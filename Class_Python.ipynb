# %% [markdown]
# '클래스(Class)'라는 것은 '설계도'와 '설명서'가 합쳐진 형태이다.
# - __init__() 등과 같은 것들을 통해 설명서를 작성하는 거임.

# %%
class BlackBox:
  pass

# %%
b1 = BlackBox() # b1 객체는 BlackBox의 인스턴스이다.
b1.name = '까망이' # 변수 선언
print(b1.name)
# Out:
# 까망이

# %%
# 특정 객체가 어느 클래스의 인스턴스인지를 확인하는 함수
print(isinstance(b1, BlackBox))
# Out:
# True

# %%
class BlackBox:
  def __init__(self, name, price):
    self.name = name
    self.price = price

# __init__(): 우리가 만든 BlackBox라는 클래스는 name과 price라는 두 개의 변수를 가지고 있는데, 객체를 만들 때 각각 name과 price를 넣어주는 초기화 역할을 함.
# __init__()은 객체가 생성될 때 자동으로 실행됨. 
# 이때 name과 price는 '멤버 변수'라고 부른다.

# %%
b1 = BlackBox('까망이', 200000)
b2 = BlackBox('하양이', 100000)

print(b1.name, b1.price)
print(b2.name, b2.price)
# Out:
# 까망이 200000
# 하양이 100000

# %%
class BlackBox:
  def __init__(self, name, price):
    self.name = name
    self.price = price
  
  def set_travel_mode(self): # 전달받는 값이 하나도 없다면 그냥 self만 적어주면 됨.
    print('여행 모드 ON')

# %%
b1 = BlackBox('까망이', 200000)
b1.set_travel_mode()
# Out:
# 여행 모드 ON

# %%
class BlackBox:
  def __init__(self, name, price):
    self.name = name
    self.price = price
  
  def set_travel_mode(self, min): # 여행 모드 시간(분)
    print(str(min) + '분 동안 여행 모드 ON')

# %%
b1 = BlackBox('까망이', 200000)
b1.set_travel_mode(20)
# Out:
# 20분 동안 여행 모드 ON

# %%
class Student:
    def introduce(self, name, age):
        print(f'제 이름은 {name}이고 {age}살입니다.')

pbj = Student()
pbj.introduce('박병준', 31)
# Out:
# 제 이름은 박병준이고 31살입니다.

# %% [markdown]
# self는 객체 자기 자신을 의미함.

# %%
class BlackBox:
  def __init__(self, name, price):
    self.name = name
    self.price = price
  
  def set_travel_mode(self, min):
    print(f'{self.name}, {min}분 동안 여행 모드 ON') # 메서드 내에서는 self.name과 같은 형태로 멤버 변수를 사용해야 한다.

# %%
b1 = BlackBox('까망이', 200000)
b2 = BlackBox('하양이', 100000)

b1.set_travel_mode(20)
b2.set_travel_mode(10)
# Out:
# 까망이, 20분 동안 여행 모드 ON
# 하양이, 10분 동안 여행 모드 ON

# %%
# BlackBox를 맨 앞에 적으면 정의된 메서드의 self 인자에 객체명을 넣어줌. 

BlackBox.set_travel_mode(b1, 20)
BlackBox.set_travel_mode(b2, 10)

# 즉, self 인자에 들어갈 것은 객체명인데, 대부분의 경우 객제명에 메서드를 호출하는 방식으로 사용하는 상황에서
# self인자에 들어갔어야 할 객체명을 이미 알고 있기 때문에 self인자를 생략하고 나머지 인자를 전달값으로 넣어주는 것임
# Out:
# 까망이, 20분 동안 여행 모드 ON
# 하양이, 10분 동안 여행 모드 ON

# %% [markdown]
# # 상속

# %%
class BlackBox:
  def __init__(self, name, price):
    self.name = name
    self.price = price

# %%
class TravelBlackBox(BlackBox):
    def set_travel_mode(self, min): # 여행 모드 시간(분)
        print(str(min) + '분 동안 여행 모드 ON')

# %%
b1 = BlackBox('까망이', 200000)
b2 = TravelBlackBox('하양이', 100000)

b2.set_travel_mode(10)
# b1 객체는 set_travel_mode() 메서드를 사용할 수 없음
# Out:
# 10분 동안 여행 모드 ON

# %% [markdown]
# ### 부모 클래스의 메서드를 상속받되, 멤버 변수가 추가되는 경우

# %%
class TravelBlackBox(BlackBox):
    def __init__(self, name, price, sd):
        BlackBox.__init__(self, name, price) # 부모 클래스의 이름을 그대로 쓰는 경우에는 self 인자를 추가해야 함.
        self.sd = sd
        # name과 price는 BlackBox 클래스를 호출해서 설정하고, sd카드 부분만 새로이 인자를 초기화해서 객체를 생성.

    def set_travel_mode(self, min):
        print(str(min + '분 동안 여행 모드 ON'))

# %%
# super를 사용

class TravelBlackBox(BlackBox):
    def __init__(self, name, price, sd):
        super().__init__(name, price) # super()를 이용하는 경우 self 인자를 사용하지 않음에 주의
        self.sd = sd
        # name과 price는 BlackBox 클래스를 호출해서 설정하고, sd카드 부분만 새로이 인자를 초기화해서 객체를 생성.

    def set_travel_mode(self, min):
        print(str(min + '분 동안 여행 모드 ON'))

# %% [markdown]
# ### Jump To Python Study

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result += num
        return self.result

# %%
cal1 = Calculator()
cal2 = Calculator()

print(cal1.add(3))
print(cal1.add(4))
print(cal2.add(3))
print(cal2.add(7))
# Out:
# 3
# 7
# 3
# 10

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result += num
        return self.result
    
    def sub(self, num):
        self.result -= num
        return self.result

# %% [markdown]
# ### 객체와 인스턴스의 차이
#     클래스로 만든 객체를 인스턴스라고도 한다. 그렇다면 객체와 인스턴스의 차이는 무엇일까? 이렇게 생각해 보자. a = Cookie() 이렇게 만든 a는 객체이다. 그리고 a 객체는 Cookie의 인스턴스이다. 즉 인스턴스라는 말은 특정 객체(a)가 어떤 클래스(Cookie)의 객체인지를 관계 위주로 설명할 때 사용한다. "a는 인스턴스"보다는 "a는 객체"라는 표현이 어울리며 "a는 Cookie의 객체"보다는 "a는 Cookie의 인스턴스"라는 표현이 훨씬 잘 어울린다.

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

# 앞에서 만든 FourCal 클래스에서 pass 문장을 삭제하고 그 대신 setdata 함수를 만들었다. 클래스 안에 구현된 함수는 다른 말로 메서드(Method)라고 부른다. 앞으로 클래스 내부의 함수는 항상 메서드라고 표현할 테니 메서드라는 용어를 기억해 두자.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result

# %%
a = FourCal()
a.setdata(4, 2)

# %%
a.add()
# Out:
# 6

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result
    
    def div(self):
        result = self.first / self.second
        return result

# %%
a = FourCal()
b = FourCal()
a.setdata(4,2)
b.setdata(3,8)

# %%
a.add()
# Out:
# 6

# %%
a.mul()
# Out:
# 8

# %%
a.div()
# Out:
# 2.0

# %%
a.sub()
# Out:
# 2

# %%
b.add()
# Out:
# 11

# %%
b.mul()
# Out:
# 24

# %%
b.sub()
# Out:
# -5

# %%
b.div()
# Out:
# 0.375

# %% [markdown]
# ![image.png](attachment:image.png)
#
#     __init__ 메서드는 setdata 메서드와 이름만 다르고 모든 게 동일하다. 단 메서드 이름을 __init__으로 했기 때문에 생성자로 인식되어 객체가 생성되는 시점에 자동으로 호출되는 차이가 있다.
#
# ![image-2.png](attachment:image-2.png)
#
#     a = FourCal()을 수행할 때 생성자 __init__이 호출되어 위와 같은 오류가 발생했다. 오류가 발생한 이유는 생성자의 매개변수 first와 second에 해당하는 값이 전달되지 않았기 때문이다.
#
#     위 오류를 해결하려면 다음처럼 first와 second에 해당되는 값을 전달하여 객체를 생성해야 한다.
#
# ![image-3.png](attachment:image-3.png)

# %%
class Mul:
    def __init__(self, m):
        self.m = m
    
    def mul(self, n):
        return self.m * n 
    
if __name__ == '__main__':
    mul3 = Mul(3)
    mul5 = Mul(5)

    print(mul3.mul(10)) # 30 출력
    print(mul5.mul(10)) # 50 출력
# Out:
# 30
# 50

# %%
class Mul:
    def __init__(self, m):
        self.m = m
    
    def __call__(self, n):
        return self.m * n 
    
if __name__ == '__main__':
    mul3 = Mul(3)
    mul5 = Mul(5)

    print(mul3(10)) # 30 출력
    print(mul5(10)) # 50 출력

# mul() 함수 이름을 __call__로 바꾸었다. __call__ 함수는 Mul 클래스로 만든 객체에 인수를 전달하여 바로 호출할 수 있도록 하는 메서드이다. __call__ 메서드를 이용하면 이 예제처럼 mul3 객체를 mul3(10)처럼 호출할 수 있다. 이렇게 클래스로 만드는 방법이 일반적이긴 하지만, 더 간편한 방법이 있다. 다음 함수를 보자.
# Out:
# 30
# 50
